# %% [markdown]
# # Dataset 作成
# - 概要
#     - 金融におけるトランザクションデータを作成
# - データ内容
#     - transaction
#     - shema
#         - transaction id
#         - 送金元
#         - 送金先
#         - 送金時刻
#         - 金額

# %% [markdown]
# # Pandas にてダミーデータをcsvで作成 Datasets vol配下に吐き出し

# %%
import random
from datetime import date, timedelta

import pandas as pd

# ダミーデータ出力先 (Datasets 用 Volume)
# DATASETS_VOL_PATH = "/Volumes/workspace/datasets/vol"
# OUTPUT_CSV_PATH = f"{DATASETS_VOL_PATH}/transaction.csv"
OUTPUT_CSV_PATH = "transaction.csv"

# トランザクションマスタ
sender = [
    "A さん", "B さん", "C さん",
    "D さん", "E さん", "F さん", "G さん",
    "H さん", "I さん", "J さん",
    "K さん", "L さん", "M さん",
]

accepter = [
    "A さん", "B さん", "C さん",
    "D さん", "E さん", "F さん", "G さん",
    "H さん", "I さん", "J さん",
    "K さん", "L さん", "M さん",
]

records = [
    {
        "transaction_id": f"P{idx + 1:03}",
        "sender": random.choice(sender),
        "accepter": random.choice(accepter),
        "time_stamp": date.today() - timedelta(days=random.randint(0, 29)),
        "amount": random.randint(100, 5000),
    }
    for idx in range(100)
]

df_pd_trans = pd.DataFrame(records)
df_pd_trans.to_csv(OUTPUT_CSV_PATH, index=False)

df_pd_trans.head()
# Out:
#   transaction_id sender accepter  time_stamp  amount
# 0           P001   C さん     E さん  2026-07-08    3019
# 1           P002   J さん     D さん  2026-07-03     673
# 2           P003   I さん     K さん  2026-07-01    1357
# 3           P004   E さん     C さん  2026-06-17    3805
# 4           P005   L さん     D さん  2026-06-27    1739

# %% [markdown]
# # Spark delta table 作成

# %%
#  ライブラリインポート
import random
from datetime import date, timedelta
from pyspark.sql.types import (
    StructType,
    StructField,
    StringType,
    DateType,
    IntegerType,
)

# %%
transaction_schema = StructType([
    StructField("transaction_id", StringType(), False),
    StructField("sender", StringType(), False),
    StructField("accepter", StringType(), False),
    StructField("time_stamp", DateType(), False),
    StructField("amount", IntegerType(), False),
])


# トランザクションマスタ
sender = [
    "A さん", "B さん", "C さん",
    "D さん", "E さん", "F さん", "G さん",
    "H さん", "I さん", "J さん",
    "K さん", "L さん", "M  さん",
]


accepter = [
    "A さん", "B さん", "C さん",
    "D さん", "E さん", "F さん", "G さん",
    "H さん", "I さん", "J さん",
    "K さん", "L さん", "M  さん",
]


trans = [
    {
        "transaction_id": f"P{idx + 1:03}",
        "sender": random.choice(sender),
        "accepter": random.choice(accepter),
        "time_stamp": date.today() - timedelta(
            days=random.randint(0, 29)
        ),
        "amount": random.randint(100, 5000)
    }
    for idx in range(100)
]

df_trans = spark.createDataFrame(trans, schema=transaction_schema)
df_trans.write.mode("overwrite").option("overwriteSchema", "true").saveAsTable("workspace.datasets.transaction")

display(df_trans)

# %%
# 作成したテーブルの確認
display(spark.read.table("workspace.datasets.transaction").limit(5))
